# %%
import pandas as pd
import matplotlib.pyplot as plt

# Указываем полный путь к файлу results.csv
data = pd.read_csv('C:\\CUDALAB\\CUDA4\\CUDA4\\results.csv')
plt.scatter(data['X'], data['Y'], label='Original Data')
plt.plot(data['X'], data['PredictedY'], color='red', label='Fitted Polynomial')
plt.legend()
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Polynomial Fit vs Original Data')
plt.show()
